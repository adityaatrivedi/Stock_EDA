# %%
import pandas as pd

file_path = "./data/NIFTY 50.csv"
df = pd.read_csv(file_path)

# Display the first few rows
print(df.head())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 4
#       1 import pandas as pd
#       3 file_path = "./data/NIFTY 50.csv"
# ----> 4 df = pd.read_csv(file_path)
#       6 # Display the first few rows
#       7 print(df.head())
#
# ...

# %%
import os
print(os.getcwd())
# Out:
# /Users/adityatrivedi/Stock_EDA/data

# %%
import os
os.chdir('/path/to/Stock_EDA')  # Replace with the actual path to your Stock_EDA folder
print(os.getcwd())  # Check if the change was successful
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 2
#       1 import os
# ----> 2 os.chdir('/path/to/Stock_EDA')  # Replace with the actual path to your Stock_EDA folder
#       3 print(os.getcwd())  # Check if the change was successful
#
# FileNotFoundError: [Errno 2] No such file or directory: '/path/to/Stock_EDA'

# %%
import pandas as pd

# Since you are already in the 'data' directory, use the filename directly
file_path = "NIFTY 50.csv"
df = pd.read_csv(file_path)

# Display the first few rows
print(df.head())
# Out:
#          Date     Open     High      Low   Close    P/E   P/B Div Yield %
# 0  2000-01-03  1482.15  1592.90  1482.15  1592.2  25.91  4.63        0.95
# 1  2000-01-04  1594.40  1641.95  1594.40  1638.7  26.67  4.76        0.92
# 2  2000-01-05  1634.55  1635.50  1555.05  1595.8  25.97  4.64        0.95
# 3  2000-01-06  1595.80  1639.00  1595.80  1617.6  26.32  4.70        0.94
# 4  2000-01-07  1616.60  1628.25  1597.20  1613.3  26.25  4.69        0.94

# %%
import pandas as pd

file_path = 'NIFTY 50.csv'  # Adjust if the filename is different
df = pd.read_csv(file_path)

# Display the first few rows to ensure it loaded correctly
print(df.head())
# Out:
#          Date     Open     High      Low   Close    P/E   P/B Div Yield %
# 0  2000-01-03  1482.15  1592.90  1482.15  1592.2  25.91  4.63        0.95
# 1  2000-01-04  1594.40  1641.95  1594.40  1638.7  26.67  4.76        0.92
# 2  2000-01-05  1634.55  1635.50  1555.05  1595.8  25.97  4.64        0.95
# 3  2000-01-06  1595.80  1639.00  1595.80  1617.6  26.32  4.70        0.94
# 4  2000-01-07  1616.60  1628.25  1597.20  1613.3  26.25  4.69        0.94

# %%
print(df.isnull().sum())
# Out:
# Date           0
# Open           0
# High           0
# Low            0
# Close          0
# P/E            0
# P/B            0
# Div Yield %    0
# dtype: int64

# %%
df = df.dropna()  # Or use df.fillna(value) for filling

# %%
print(df.describe())
# Out:
#                Open          High           Low        Close          P/E  \
# count   5970.000000   5970.000000   5970.000000   5970.00000  5970.000000
# mean    6907.663819   6949.017027   6856.590109   6903.95376    20.907717
# std     5118.079883   5134.187769   5091.789342   5114.08714     4.943233
# min      853.000000    877.000000    849.950000    854.20000    10.680000
# 25%     2651.812500   2693.837500   2613.112500   2654.60000    17.662500
# 50%     5561.475000   5598.300000   5513.350000   5555.15000    20.710000
# 75%    10060.975000  10109.512500  10001.287500  10045.98750    23.430000
# max    21751.350000  21834.350000  21680.850000  21778.70000    42.000000
#
#                P/B
# count  5970.000000
# mean      3.621576
# std       0.778840
# min       1.920000
# 25%       3.090000
# 50%       3.530000
# 75%       4.090000
# max       6.550000

# %%
print(df.dtypes)
# Out:
# Date            object
# Open           float64
# High           float64
# Low            float64
# Close          float64
# P/E            float64
# P/B            float64
# Div Yield %     object
# dtype: object

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Plotting Closing Prices Over Time
plt.figure(figsize=(10, 5))
plt.plot(pd.to_datetime(df['Date']), df['Close'], label='Close Price')
plt.title('NIFTY 100 Closing Prices')
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.show()

# %%
sns.histplot(df['Close'], bins=30, kde=True)
plt.title('Distribution of Closing Prices')
plt.show()

# %%
df['MA50'] = df['Close'].rolling(window=50).mean()
df['MA200'] = df['Close'].rolling(window=200).mean()

plt.figure(figsize=(12, 6))
plt.plot(df['Date'], df['Close'], label='Close Price')
plt.plot(df['Date'], df['MA50'], label='50-Day MA')
plt.plot(df['Date'], df['MA200'], label='200-Day MA')
plt.title('Moving Averages of NIFTY 100')
plt.legend()
plt.show()

# %%
df.to_csv('cleaned_NIFTY_50.csv', index=False)

# %%
# !ls
# Out:
# NIFTY 50.csv         Untitled.ipynb       cleaned_NIFTY_50.csv

# %%
from IPython.display import FileLink
FileLink('cleaned_NIFTY_50.csv')
# Out:
# /Users/adityatrivedi/Stock_EDA/data/cleaned_NIFTY_50.csv
